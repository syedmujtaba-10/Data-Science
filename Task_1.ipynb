# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/AmenaNajeeb/Data/master/CardioGoodFitness.csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.mean()
# Out:
# C:\Users\SYEDMU~1\AppData\Local\Temp/ipykernel_5804/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# dtype: float64

# %%
df.shape
# Out:
# (180, 9)

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df.head(20)
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 3    TM195   19    Male         12        Single      3        3   32973
# 4    TM195   20    Male         13     Partnered      4        2   35247
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 7    TM195   21    Male         13        Single      3        3   32973
# 8    TM195   21    Male         15        Single      5        4   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 10   TM195   22    Male         14        Single      3        3   36384
# 11   TM195   22  Female         14     Partnered      3        2   35247
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=180, step=1),
#  Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#         'Fitness', 'Income', 'Miles'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df1=df.sample

# %%
df1
# Out:
# <bound method NDFrame.sample of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
df[['Education']]
# Out:
#      Education
# 0           14
# 1           15
# 2           14
# 3           12
# 4           13
# ..         ...
# 175         21
# 176         18
# 177         16
# 178         18
# 179         18
#
# [180 rows x 1 columns]

# %%
df[['Education']].std()
# Out:
# Education    1.617055
# dtype: float64

# %%
df_Income=df.groupby(['Income'])

# %%
df_Income

# %%
df_Income.mean()
# Out:
#          Age  Education  Usage  Fitness  Miles
# Income
# 29562   18.0       14.0    3.0      4.0  112.0
# 30699   19.0       14.0    4.0      3.0   66.0
# 31836   19.0       14.5    2.5      3.0   69.5
# 32973   20.2       13.0    2.6      2.8   68.4
# 34110   21.6       14.6    2.8      2.8  100.2
# ...      ...        ...    ...      ...    ...
# 95508   48.0       18.0    4.0      5.0  180.0
# 95866   33.0       18.0    4.0      5.0  200.0
# 99601   30.0       18.0    5.0      5.0  150.0
# 103336  30.0       18.0    5.0      4.0  160.0
# 104581  42.5       18.0    4.5      5.0  135.0
#
# [62 rows x 5 columns]

# %%
df_sub=df[df['Income']>49000]

# %%
df_sub
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 29    TM195   25  Female         14     Partnered      2        2   53439
# 35    TM195   26  Female         16     Partnered      4        3   52302
# 36    TM195   26    Male         16     Partnered      2        2   53439
# 37    TM195   26    Male         16     Partnered      3        3   51165
# 40    TM195   26    Male         16        Single      3        3   50028
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 29      47
# 35     113
# 36      47
# 37      85
# 40      85
# ...

# %%
df_Gender=df.groupby(['Gender'])

# %%
df_Gender.mean()
# Out:
#               Age  Education     Usage   Fitness        Income       Miles
# Gender
# Female  28.565789  15.394737  3.184211  3.026316  49828.907895   90.013158
# Male    28.951923  15.701923  3.653846  3.519231  56562.759615  112.826923

# %%
df[['Age','Education']].agg(['min','mean','max'])
# Out:
#             Age  Education
# min   18.000000  12.000000
# mean  28.788889  15.572222
# max   50.000000  21.000000
